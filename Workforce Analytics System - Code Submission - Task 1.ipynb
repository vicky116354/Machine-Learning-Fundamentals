# %%
import pandas as pd
df = pd.read_csv("hr_analytics.xls")

# %%
#Q1
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1000
# Columns: 10

# %%
#Q2
print(df.dtypes)
# Out:
# Age                  int64
# Gender                 str
# Department             str
# MonthlyIncome        int64
# TotalWorkingYears    int64
# YearsAtCompany       int64
# JobSatisfaction      int64
# WorkLifeBalance      int64
# OverTime               str
# Attrition              str
# dtype: object

# %%
#Q3
print(df.isnull().sum())
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %%
#Q4
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
#Q5
print("Total Employees:", len(df))
# Out:
# Total Employees: 1000

# %%
#Q6
print("Number of Departments:", df["Department"].nunique())
# Out:
# Number of Departments: 3

# %%
#Q7
print(df["Department"].unique())
# Out:
# <ArrowStringArray>
# ['HR', 'R&D', 'Sales']
# Length: 3, dtype: str

# %%
#Q8
print("Average Age:", df["Age"].mean())
# Out:
# Average Age: 40.947

# %%
#Q9
print("Minimum Age:", df["Age"].min())
print("Maximum Age:", df["Age"].max())
# Out:
# Minimum Age: 22
# Maximum Age: 59

# %%
#Q10
print(df["Gender"].value_counts())
# Out:
# Gender
# Male      504
# Female    496
# Name: count, dtype: int64

# %%
#Q11
print(df["Department"].value_counts())
# Out:
# Department
# HR       352
# Sales    343
# R&D      305
# Name: count, dtype: int64

# %%
#Q12
count = df[df["TotalWorkingYears"] > 10].shape[0]
print("Employees with more than 10 years of experience:", count)
# Out:
# Employees with more than 10 years of experience: 720

# %%
#Q13
count = df[df["YearsAtCompany"] > 5].shape[0]
print("Employees with more than 5 years at company:", count)
# Out:
# Employees with more than 5 years at company: 752

# %%
#Q14
avg_income = df.groupby("Department")["MonthlyIncome"].mean()
print(avg_income)
# Out:
# Department
# HR       11604.042614
# R&D      11461.272131
# Sales    11417.247813
# Name: MonthlyIncome, dtype: float64

# %%
#Q15
left_emp = df[df["Attrition"] == "Yes"].groupby("Department").size()
print(left_emp)
# Out:
# Department
# HR       70
# R&D      74
# Sales    59
# dtype: int64
